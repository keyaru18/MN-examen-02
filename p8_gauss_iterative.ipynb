# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Ejercicio 1

# %%
# %load_ext autoreload
# %autoreload 2
from src import eliminacion_gaussiana, gauss_jacobi, gauss_seidel
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
A = [[2,1],[3,2]]
b = [5,8]
n = len(b)

# %%
gauss_jacobi(A=A, b=b, x=[0] * n, tol=1e-5, max_iter=10)  
gauss_seidel(A=A, b=b, x=[0] * n, tol=1e-5, max_iter=10)
# Out:
# [01-29 13:41:50][INFO][DELL] i= 0 x: [[0. 0.]]
# [01-29 13:41:50][INFO][DELL] i= 10 x: [[1.52539062 0.76269531]]
# [01-29 13:41:50][INFO][DELL] i= 0 x: [[0. 0.]]
# [01-29 13:41:50][INFO][DELL] i= 1 x: [[2.5  0.25]]
# [01-29 13:41:50][INFO][DELL] i= 2 x: [[2.375  0.4375]]
# [01-29 13:41:50][INFO][DELL] i= 3 x: [[2.28125  0.578125]]
# [01-29 13:41:50][INFO][DELL] i= 4 x: [[2.2109375  0.68359375]]
# [01-29 13:41:50][INFO][DELL] i= 5 x: [[2.15820312 0.76269531]]
# [01-29 13:41:50][INFO][DELL] i= 6 x: [[2.11865234 0.82202148]]
# [01-29 13:41:50][INFO][DELL] i= 7 x: [[2.08898926 0.86651611]]
# [01-29 13:41:50][INFO][DELL] i= 8 x: [[2.06674194 0.89988708]]
# [01-29 13:41:50][INFO][DELL] i= 9 x: [[2.05005646 0.92491531]]
# [01-29 13:41:50][INFO][DELL] i= 10 x: [[2.03754234 0.94368649]]
# array([[2.03754234],
#        [0.94368649]])

# %% [markdown]
# # Código para dibujar

# %%
# graficar
x_values = [0, 1.52539062, 0, 2.5, 2.375, 2.28125, 2.2109375, 2.15820312, 2.11865234, 2.08898926,2.06674194, 2.05005646, 2.03754234 ]
y_values = [0, 0.76269531, 0, 0.25, 0.4375, 0.578125,0.68359375,0.76269531,0.82202148,0.86651611,0.89988708,0.92491531,0.94368649]  
import matplotlib.pyplot as plt

iterations = range(len(x_values))

# Dibujar trajectoria en el espacio 2D
plt.plot(x_values, y_values, "o:", markersize=4)
plt.plot(x_values[0], y_values[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values[-1], y_values[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Determine la pendiente de la línea de convergencia
import numpy as np
x = np.array(x_values)
y = np.array(y_values)
A = np.vstack([x, np.ones(len(x))]).T
m, c = np.linalg.lstsq(A, y, rcond=None)[0]
print(f"Pendiente de la línea de convergencia: {m}")
# Out:
# Pendiente de la línea de convergencia: 0.2716806346658689

# %% [markdown]
# # Ejercicio 2

# %%
A = [[1,1],[-2,1]]
b = [6,0]

# %%
gauss_jacobi(A=A, b=b, x=[0] * n, tol=1e-5, max_iter=10)  
gauss_seidel(A=A, b=b, x=[0] * n, tol=1e-5, max_iter=10)
# Out:
# [01-29 13:40:00][INFO][DELL] i= 0 x: [[0. 0.]]
# [01-29 13:40:00][INFO][DELL] i= 10 x: [[ 66. 132.]]
# [01-29 13:40:00][INFO][DELL] i= 0 x: [[0. 0.]]
# [01-29 13:40:00][INFO][DELL] i= 1 x: [[ 6. 12.]]
# [01-29 13:40:00][INFO][DELL] i= 2 x: [[ -6. -12.]]
# [01-29 13:40:00][INFO][DELL] i= 3 x: [[18. 36.]]
# [01-29 13:40:00][INFO][DELL] i= 4 x: [[-30. -60.]]
# [01-29 13:40:00][INFO][DELL] i= 5 x: [[ 66. 132.]]
# [01-29 13:40:00][INFO][DELL] i= 6 x: [[-126. -252.]]
# [01-29 13:40:00][INFO][DELL] i= 7 x: [[258. 516.]]
# [01-29 13:40:00][INFO][DELL] i= 8 x: [[ -510. -1020.]]
# [01-29 13:40:00][INFO][DELL] i= 9 x: [[1026. 2052.]]
# [01-29 13:40:00][INFO][DELL] i= 10 x: [[-2046. -4092.]]
# array([[-2046.],
#        [-4092.]])

# %% [markdown]
# # Código para dibujar

# %%
# Extraer valores de la trayectoria
# -- Datos de ejemplo --
x_values = [0,66,0,6,-6,18,-30,66,-126,258,-510,1026,-2046]
y_values = [0,132,0,12,-12,36,-60,132,-252,516,-1020,2052,-4092]

import matplotlib.pyplot as plt

iterations = range(len(x_values))

# Dibujar trajectoria en el espacio 2D
plt.plot(x_values, y_values, "o:", markersize=4)
plt.plot(x_values[0], y_values[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values[-1], y_values[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
