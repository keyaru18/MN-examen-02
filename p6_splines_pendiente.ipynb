# %% [markdown]
# # Splines cúbicos

# %%
def Spline(x: float, x0: float, pars: dict[str, float]) -> float:
    a = pars["a"]
    b = pars["b"]
    c = pars["c"]
    d = pars["d"]
    return a + b * (x - x0) + c * (x - x0) ** 2 + d * (x - x0) ** 3

# %%
import matplotlib.pyplot as plt
import numpy as np

xs = [-1, 0, 1]
ys = [1, 5, 3]
s = [
    {"a": 1, "b": 5.5, "c": 0, "d": -1.5},
    {"a": 5, "b": 1, "c": -4.5, "d": 1.5},
]
for i, x_i in enumerate(xs[:-1]):
    _x = np.linspace(x_i, xs[i + 1], 20)
    _y = Spline(_x, x_i, s[i])
    plt.plot(_x, _y, color="red")

plt.scatter(xs, ys)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Interpolación con splines cúbicos")
plt.show()

# %% [markdown]
# # Tarea
# * Grafique los splines cúbicos tal que cumplan con la pendiente $m$ deseada en el punto $(x_1,y_1)$.

# %%
import matplotlib.pyplot as plt
import numpy as np

def Spline(x_val, x_k, coeff):
    dx = x_val - x_k
    return coeff["a"] + coeff["b"] * dx + coeff["c"] * dx**2 + coeff["d"] * dx**3

xs = [-1, 0, 1]
ys = [1, 5, 3]
s = [
    {"a": 1, "b": 7, "c": 0, "d": -3},
    {"a": 5, "b": -2, "c": 0, "d": 0},
]

for i, x_i in enumerate(xs[:-1]):
    _x = np.linspace(x_i, xs[i + 1], 20)
    _y = Spline(_x, x_i, s[i])
    plt.plot(_x, _y, color="red")

plt.scatter(xs, ys)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Interpolación con splines cúbicos")
plt.show()

# %%
#graficar la pendiente m = -2 junto con los splines cúbicos anteriores
import matplotlib.pyplot as plt
import numpy as np
def Spline(x_val, x_k, coeff):
    dx = x_val - x_k
    return coeff["a"] + coeff["b"] * dx + coeff["c"] * dx**2 + coeff["d"] * dx**3
xs = [-1, 0, 1]
ys = [1, 5, 3]
s = [
    {"a": 1, "b": 7, "c": 0, "d": -3},
    {"a": 5, "b": -2, "c": 0, "d": 0},
]
for i, x_i in enumerate(xs[:-1]):
    _x = np.linspace(x_i, xs[i + 1], 20)
    _y = Spline(_x, x_i, s[i])
    plt.plot(_x, _y, color="red")
# Graficar la línea con pendiente m = -2
m = -2
x_line = np.linspace(-1, 1, 100)
y_line = m * (x_line - 0) + 5  # La línea
plt.plot(x_line, y_line, color="blue", linestyle="--", label="Línea m = -2")
plt.scatter(xs, ys)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Interpolación con splines cúbicos y línea m = -2")
plt.legend()
plt.show()
